# %% [markdown]
# <a href="https://colab.research.google.com/github/henrykibithia8-dev/DS-projests/blob/main/Simple_linear_regression_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple linear regression

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv("https://github.com/henrykibithia8-dev/DS-projests/raw/main/Simple%20linear%20regression.csv")
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and independent variables

# %%
x = data.drop(['GPA'], axis= 1)
y = data['GPA']

# %%
x.shape
# Out:
# (84, 1)

# %%
y.shape
# Out:
# (84,)

# %% [markdown]
# ### Regression itself

# %%
reg = LinearRegression()

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
#lets get R_squared
reg.score(x, y)
# Out:
# 0.40600391479679754

# %%
reg.coef_
# Out:
# array([0.00165569])

# %%
reg.intercept_
# Out:
# np.float64(0.2750402996602799)

# %%
import numpy as np
#predict new data
reg.predict(np.array(1740).reshape(-1, 1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.15593751])

# %%
import numpy as np
new_data = pd.DataFrame(data=[[1740, np.nan], [1760, np.nan]], columns=["SAT", "GPA"])
new_data
# Out:
#     SAT  GPA
# 0  1740  NaN
# 1  1760  NaN

# %%
reg.predict(new_data[['SAT']])
# Out:
# array([3.15593751, 3.18905127])

# %%
plt.scatter(x,y)
yhat = reg.coef_*x + reg.intercept_
fig = plt.plot(x, yhat, c = "r")
plt.show()
