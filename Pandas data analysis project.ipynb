# %%
import pandas as pd

# %%
#creating dataset using dict
dataset = {
    "Cars" : ["BMW", "Volvo", "Ford"],
    "Dispars" : [3, 7, 2]
}
df = pd.DataFrame(dataset)
df
# Out:
#     Cars  Dispars
# 0    BMW        3
# 1  Volvo        7
# 2   Ford        2

# %%
df1 = df.to_csv()

# %%
print(df.head().to_string(index=False))
# Out:
#  Cars  Dispars
#   BMW        3
# Volvo        7
#  Ford        2

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
#creating pandas array
a = [1, 7, 2]
myvar = pd.Series(a)
myvar
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#With the index argument, you can name your own labels.

myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
#accessing an item by referring to label
y = print(myvar["y"])
# Out:
# 7

# %%
#Key/Value Objects as Series

calories = {"day1": 420, "day2": 380, "day3": 390}
calories = print(pd.Series(calories))
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
#Create a DataFrame from two Series:
#Series is like a column, a DataFrame is the whole table.

data = {
    "calories": [420, 380, 390],
    "duration": [50, 45, 55]
}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    calories  duration
# 0       420        50
# 1       380        45
# 2       390        55

# %%
import pandas as pd

#s you can see from the result above, the DataFrame is like a table with rows and columns.

#Pandas use the loc attribute to return one or more specified row(s)

#Create a DataFrame from two Series:
#Series is like a column, a DataFrame is the whole table.

data = {
    "calories": [420, 380, 390],
    "duration": [50, 45, 55]
}
df = pd.DataFrame(data)

# %%
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#use a list of indexes: row 0 and 1
print(df.loc[:2])
# Out:
#    calories  duration
# 0       420        50
# 1       380        45
# 2       390        55

# %%
#Add a list of names to give each row a name:

data = ({
  "calories": [420, 380, 390],
  "duration": [50, 40, 45],
})

df = print(pd.DataFrame(data, index = ["Henry", "Kennedy", "Roy"]))
# Out:
#          calories  duration
# Henry         420        50
# Kennedy       380        40
# Roy           390        45

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["Henry", "Kennedy", "Roy"])

#adding new data 
nd = [55, 50, 54]
df.insert(loc = 1, column = "Weight", value = nd)

# %%
df
# Out:
#          calories  Weight  duration
# Henry         420      55        50
# Kennedy       380      50        40
# Roy           390      54        45

# %%
#Use the named index in the loc attribute to return the specified row(s).
print(df.loc["Henry"])
# Out:
# calories    420
# Weight       55
# duration     50
# Name: Henry, dtype: int64

# %%
"""
Read CSV Files
A simple way to store big data sets is to use CSV files (comma separated files).

CSV files contains plain text and is a well know format that can be read by everyone including Pandas.

In our examples we will be using a CSV file called 'data.csv'."""
# Out:
# "\nRead CSV Files\nA simple way to store big data sets is to use CSV files (comma separated files).\n\nCSV files contains plain text and is a well know format that can be read by everyone including Pandas.\n\nIn our examples we will be using a CSV file called 'data.csv'."

# %%
df = pd.read_csv("https://www.w3schools.com/python/pandas/data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.shape
# Out:
# (169, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
#checking max rows your comp can display
print(pd.options.display.max_rows)
# Out:
# 9999

# %%
#Increasing the number of rows to display df
pd.options.display.max_rows = 9999
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# Pandas read **JSON**

# %%
df = pd.read_json("https://www.w3schools.com/python/pandas/data.js")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %% [markdown]
# JSON = Python Dictionary
#
# JSON objects have the same format as Python dictionaries.
#
#
# If your JSON code is not in a file, but in a Python Dictionary, you can load it into a DataFrame directly:

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

# %%
df = pd.DataFrame(data)
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# Pandas analyzing data
#
#
# **Data Cleaning**
#
#
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# Empty cells
# Data in wrong format
# Wrong data
# Duplicates

# %%
#import dataset from my Github
df1 = pd.read_csv("https://raw.githubusercontent.com/henrykibithia8-dev/DS-projests/main/exercise_dataset.csv")

df2= pd.read_csv("https://raw.githubusercontent.com/henrykibithia8-dev/DS-projests/main/exercise_dataset.csv")

# %%
print(f"Head:\n", df1.head())  #the first 5 rows
print(f"\nHead:\n", df1.tail()) #the last 5 rows
# Out:
# Head:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0
#
# Head:
#      Duration        Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27     92       118     241.0
# 28        60  2020/12/28    103       132       NaN
# 29        60  2020/12/29    100       132     280.0
# 30        60  2020/12/30    102       129     380.3
# 31        60  2020/12/31     92       115     243.0

# %% [markdown]
# **Remove Rows**
#
#
# One way to deal with empty cells is to **remove rows that contain empty cells**.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

# %%
#remove empty rows
print(df1.dropna(inplace=True)) #If you want to change the original DataFrame, use the inplace=True arg

new_df = df1.dropna()
print(new_df) #dropna() method returns a new DataFrame, and will not change the original.
# Out:
# None
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df2
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#after cleaning calories col
df2.fillna({"Calories": 190}, inplace = True)
df2
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %% [markdown]
# **Cleaning Data of Wrong Format**

# %%
#remove the rows, or convert all cells in the columns into the same format.
"""
In our Data Frame, we have two cells with the wrong format. Check out row 22 and 26, 
the 'Date' column should be a string that represents a date:
"""
#to_datetime method()
df2["Date"] = pd.to_datetime(df2["Date"], format = "mixed") #will fix row 26 only
df2
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
#Remove rows(is the only solution sometimes) with a NULL value in the "Date" column:

df2.dropna(subset=["Date"], inplace = True)
df2
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df2.shape
# Out:
# (31, 5)

# %%
#Get the mean of Duration column to replace the value
print(df.Duration.mean())
# Out:
# 55.0

# %%
df2.loc[7, "Duration"] = 150 #for small dataset(intentionally put 150 to accommodate next formula)

# %%
df2
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        150 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
#For big Dataset
"""
To replace wrong data for larger data sets you can create some rules, 
e.g. set some boundaries for legal values, 
and replace any values that are outside of the boundaries.
"""
# Out:
# '\nTo replace wrong data for larger data sets you can create some rules, \ne.g. set some boundaries for legal values, \nand replace any values that are outside of the boundaries.\n'

# %%
# I will Loop through all values in the "Duration" column.
#If the value is higher than 120, set it to 120:
for x in df2.index:
    if df2.loc[x, "Duration"] >120:
        df2.loc[x, "Duration"] = 55

# %%
df2
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         55 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df2 #view the cleaned dataset
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         55 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
print(df2.duplicated()) #we have on duplicate at row 12
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %% [markdown]
# **Removing Duplicates**

# %%
#use drop_duolicate method
df2.drop_duplicates(inplace = True)

# %%
df2
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7         55 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# 17        60 2020-12-17    100       120     300.0
# ...

# %%
df2.describe()
# Out:
#         Duration                 Date       Pulse    Maxpulse    Calories
# count  30.000000                   30   30.000000   30.000000   30.000000
# mean   56.333333  2020-12-15 19:12:00  103.733333  129.100000  299.590000
# min    30.000000  2020-12-01 00:00:00   90.000000  101.000000  190.000000
# 25%    60.000000  2020-12-08 06:00:00  100.000000  120.750000  247.000000
# 50%    60.000000  2020-12-15 12:00:00  103.000000  128.500000  291.200000
# 75%    60.000000  2020-12-23 18:00:00  107.500000  132.750000  343.975000
# max    60.000000  2020-12-31 00:00:00  130.000000  175.000000  479.000000
# std     7.535357                  NaN    8.042702   13.215325   71.543574

# %%
df2.corr()
# Out:
#           Duration      Date     Pulse  Maxpulse  Calories
# Duration  1.000000  0.180992 -0.084968 -0.290524  0.340564
# Date      0.180992  1.000000 -0.369328 -0.517827 -0.412244
# Pulse    -0.084968 -0.369328  1.000000  0.261426  0.534696
# Maxpulse -0.290524 -0.517827  0.261426  1.000000  0.359078
# Calories  0.340564 -0.412244  0.534696  0.359078  1.000000
